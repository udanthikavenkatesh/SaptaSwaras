# %% [markdown]
# # Swaras Extraction and Evaluation from Audio 🎶🎼
# This notebook focuses on extracting swaras from an audio file and evaluating the accuracy of the extraction process.
#
# **Key Components:**
# **Dominant Frequency Extraction:**
#
# Splits the audio into segments of a given window size.
#
# Identifies the most prominent frequency in each segment.
#
# **Swaras Conversion:**
#
# Converts dominant frequencies into musical notes.
#
# Maps notes to Indian classical swaras using note_to_svara_c().
#
# **Filtering Conflicting Swaras:**
#
# Resolves cases where multiple variants of a swara (e.g., R1 vs. R2) appear.
#
# Retains only the most frequent variant.
#
# **Evaluation Metrics:**
#
# Compares extracted swaras with actual aarohanam (ascending scale).
#
# Computes Precision, Recall, F1 Score, and Accuracy.
#
# This notebook provides a structured approach to analyzing Indian classical music using signal processing and machine learning techniques.

# %%
import librosa
import numpy as np
from librosa import hz_to_note,note_to_svara_c
from scipy.io import wavfile

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import librosa
from collections import Counter

# Function to extract dominant swara frequencies from audio for each segment of specified window size
def extract_dominant_swara_frequencies(file_path, window_size):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=None)

    # Calculate the number of samples per window (based on window size)
    samples_per_window = int(window_size * sr)

    # Initialize a list to store the dominant frequency for each window
    dominant_frequencies_per_window = []

    # Loop through the audio signal in increments of the specified window size
    for start in range(0, len(y), samples_per_window):
        # Extract a segment of the specified window size
        segment = y[start:start + samples_per_window]

        if len(segment) == 0:
            continue

        # Calculate the STFT for the segment
        stft = np.abs(librosa.stft(segment))
       # stft = np.abs(librosa.stft(segment, n_fft=2048, hop_length=512))

        # Get the average STFT across time for this segment
        avg_stft = np.mean(stft, axis=1)

        # Get the corresponding frequencies for each bin
        freqs = librosa.fft_frequencies(sr=sr)

        # Handle cases where avg_stft contains inf or NaN
        avg_stft = np.nan_to_num(avg_stft, nan=0.0, posinf=0.0, neginf=0.0)

        # Extract the frequency with the highest amplitude (dominant frequency)
        dominant_freq = freqs[np.argmax(avg_stft)]

        # Debugging: Print dominant frequency to ensure it's not inf or NaN
        print(f"Calculated dominant frequency: {dominant_freq}")

        # Store the dominant frequency for this segment if valid
        if np.isfinite(dominant_freq) and dominant_freq > 0:
            dominant_frequencies_per_window.append(dominant_freq)
        else:
            print(f"Skipping invalid dominant frequency: {dominant_freq}")

    return dominant_frequencies_per_window

# Dummy implementation for note_to_svara_c
def note_to_svara_c(notes):
    notes = librosa.note_to_svara_c(notes, Sa='C3', mela=16)
   # notes = librosa.note_to_svara_h(notes,Sa='F4')
    return notes

# Function to remove conflicting swaras (e.g., R1 vs R2) by keeping the most frequent one
def filter_swaras(swara_list):
    # Count occurrences of each swara
    swara_count = Counter(swara_list)

    # Group swaras by their base name (e.g., group all R1, R2, R3 as R)
    swara_groups = {}
    for swara in swara_count:
        base_swara = swara[0]  # Get the first character (e.g., R, G, M, etc.)
        if base_swara not in swara_groups:
            swara_groups[base_swara] = []
        swara_groups[base_swara].append(swara)

    # For each group (e.g., R), keep only the swara with the highest count
    final_swaras = []
    for base_swara, variants in swara_groups.items():
        # Find the variant with the maximum count
        max_swara = max(variants, key=lambda swara: swara_count[swara])
        final_swaras.append(max_swara)

    return final_swaras

# Merge function to extract dominant frequencies and convert to swaras
def extract_swaras_from_audio(file_path, window_size):
    # Step 1: Extract dominant swara frequencies for each segment of the specified window size
    dominant_swara_freqs = extract_dominant_swara_frequencies(file_path, window_size)

    # Step 2: Filter out any invalid frequencies (NaN, inf)
    valid_frequencies = [freq for freq in dominant_swara_freqs if np.isfinite(freq) and freq > 0]

    # Debugging: Print the valid frequencies
    print(f"Valid dominant frequencies: {valid_frequencies}")

    # Step 3: Convert each frequency to its corresponding musical note
    try:
        notes = [librosa.hz_to_note(freq) for freq in valid_frequencies]
        print(notes)
    except Exception as e:
        print(f"Error in hz_to_note conversion: {e}")
        return

    # Step 4: Apply note_to_svara_c to the list of notes to get swaras
    try:
        svara_notes = note_to_svara_c(notes)
    except Exception as e:
        print(f"Error in note_to_svara_c: {e}")
        return

    # Collect all swaras (dominant frequency -> note -> svara)
    all_swaras = []
    for segment, (freq, note, svara) in enumerate(zip(valid_frequencies, notes, svara_notes)):
        print(f"Segment {segment + 1}: Frequency -> {freq:.2f} Hz -> Note: {note} -> Svara: {svara}")
        all_swaras.append(svara)

    # Step 5: Filter out conflicting swaras (e.g., R1 vs R2) and retain only the most frequent variant
    final_swaras = filter_swaras(all_swaras)

    # Print the final list of swaras
    print(f"Final Swaras: {final_swaras}")

# Example usage
audio_file_path = '/content/drive/MyDrive/keys_songs/vasantha/vasa 50 C6.mp3'

# You can now dynamically change the window size
window_size = float(input("Enter the window size in seconds (e.g., 0.5, 1, 2): "))
extract_swaras_from_audio(audio_file_path, window_size)
# Out:
# Enter the window size in seconds (e.g., 0.5, 1, 2): 0.1
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 4242.041015625
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 2131.787109375
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 2131.787109375
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 1981.0546875
# Calculated dominant frequency: 2002.587890625
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1765.72265625
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1399.658203125
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1313.525390625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1119.7265625
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 4242.041015625
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 2110.25390625
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 1055.126953125
# Calculated dominant frequency: 2088.720703125
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Calculated dominant frequency: 0.0
# Skipping invalid dominant frequency: 0.0
# Valid dominant frequencies: [np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(4242.041015625), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(2110.25390625), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(2002.587890625), np.float64(2002.587890625), np.float64(2002.587890625), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(2002.587890625), np.float64(2131.787109375), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2131.787109375), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2110.25390625), np.float64(2002.587890625), np.float64(2002.587890625), np.float64(2002.587890625), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(1981.0546875), np.float64(2002.587890625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1765.72265625), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1399.658203125), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1313.525390625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1119.7265625), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(4242.041015625), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(2110.25390625), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), np.float64(1055.126953125), ...
# ['C6', 'C6', 'C6', 'C8', 'C6', 'C6', 'C7', 'C6', 'C6', 'C6', 'C6', 'C6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'C7', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'B6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'A6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'F6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'E6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C♯6', 'C6', 'C6', 'C6', 'C8', 'C6', 'C6', 'C7', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C6', 'C7']
# Segment 1: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 2: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 3: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 4: Frequency -> 4242.04 Hz -> Note: C8 -> Svara: S
# Segment 5: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 6: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 7: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 8: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 9: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 10: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 11: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 12: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 13: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 14: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 15: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 16: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 17: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 18: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 19: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 20: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 21: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 22: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 23: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 24: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 25: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 26: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 27: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 28: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 29: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 30: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 31: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 32: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 33: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 34: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 35: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 36: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 37: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 38: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 39: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 40: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 41: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 42: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 43: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 44: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 45: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 46: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 47: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 48: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 49: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 50: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 51: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 52: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 53: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 54: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 55: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 56: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 57: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 58: Frequency -> 2131.79 Hz -> Note: C7 -> Svara: S
# Segment 59: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 60: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 61: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 62: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 63: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 64: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 65: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 66: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 67: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 68: Frequency -> 2131.79 Hz -> Note: C7 -> Svara: S
# Segment 69: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 70: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 71: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 72: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 73: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 74: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 75: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 76: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 77: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 78: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 79: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 80: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 81: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 82: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 83: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 84: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 85: Frequency -> 1981.05 Hz -> Note: B6 -> Svara: N₃
# Segment 86: Frequency -> 2002.59 Hz -> Note: B6 -> Svara: N₃
# Segment 87: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 88: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 89: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 90: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 91: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 92: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 93: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 94: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 95: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 96: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 97: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 98: Frequency -> 1765.72 Hz -> Note: A6 -> Svara: D₂
# Segment 99: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 100: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 101: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 102: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 103: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 104: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 105: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 106: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 107: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 108: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 109: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 110: Frequency -> 1399.66 Hz -> Note: F6 -> Svara: M₁
# Segment 111: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 112: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 113: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 114: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 115: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 116: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 117: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 118: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 119: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 120: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 121: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 122: Frequency -> 1313.53 Hz -> Note: E6 -> Svara: G₃
# Segment 123: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 124: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 125: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 126: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 127: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 128: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 129: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 130: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 131: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 132: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 133: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 134: Frequency -> 1119.73 Hz -> Note: C♯6 -> Svara: R₁
# Segment 135: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 136: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 137: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 138: Frequency -> 4242.04 Hz -> Note: C8 -> Svara: S
# Segment 139: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 140: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 141: Frequency -> 2110.25 Hz -> Note: C7 -> Svara: S
# Segment 142: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 143: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 144: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 145: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 146: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 147: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 148: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 149: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 150: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 151: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 152: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 153: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 154: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 155: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 156: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 157: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 158: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 159: Frequency -> 1055.13 Hz -> Note: C6 -> Svara: S
# Segment 160: Frequency -> 2088.72 Hz -> Note: C7 -> Svara: S
# Final Swaras: [np.str_('S'), np.str_('G₃'), np.str_('M₁'), np.str_('D₂'), np.str_('N₃'), np.str_('R₁')]

# %%
def calculate_metrics(actual_swaras, extracted_swaras):
    # Convert to sets to allow easy comparison
    actual_set = set(actual_swaras)
    extracted_set = set(extracted_swaras)

    # True Positives (TP): Correctly identified swaras
    true_positives = actual_set.intersection(extracted_set)

    # False Positives (FP): Incorrectly identified swaras
    false_positives = extracted_set.difference(actual_set)

    # False Negatives (FN): Missed swaras
    false_negatives = actual_set.difference(extracted_set)

    # Precision: TP / (TP + FP)
    precision = len(true_positives) / (len(true_positives) + len(false_positives)) if (len(true_positives) + len(false_positives)) > 0 else 0

    # Recall: TP / (TP + FN)
    recall = len(true_positives) / (len(true_positives) + len(false_negatives)) if (len(true_positives) + len(false_negatives)) > 0 else 0

    # F1 Score: 2 * (Precision * Recall) / (Precision + Recall)
    f1_score = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # Accuracy: TP / (TP + FP + FN)
    accuracy = len(true_positives) / (len(true_positives) + len(false_positives) + len(false_negatives)) if (len(true_positives) + len(false_positives) + len(false_negatives)) > 0 else 0

    return precision, recall, f1_score, accuracy

# Example usage:
actual_aarohanam = ['S','R2', 'G2', 'M1','D2']
extracted_aarohanam = ['S','R2','G2', 'M1', 'P', 'D2', 'N2']

precision, recall, f1_score, accuracy = calculate_metrics(actual_aarohanam, extracted_aarohanam)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1_score:.2f}")
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Precision: 0.71
# Recall: 1.00
# F1 Score: 0.83
# Accuracy: 0.71
